# %% [markdown]
# ## Configuracion API Google Sheets

# %% [markdown]
# ### Crear nuevo projecto

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Seleccionar projecto

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Habilitar API

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Selecciona Credenciales y luego Administrar cuenta de servicio

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Crear cuenta de servicio

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Asignar rol de Editor

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Cuenta de servicio creada

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Seleccionamos cuenta servicio y creamos nueva clave JSON

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Descargara un JSON con las credenciales

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Compartir documento con Cuenta de servicio

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
